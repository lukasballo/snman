# %%
import warnings

warnings.filterwarnings('ignore')

import os

import snman
from snman.constants import *
from snman import osmnx_customized as oxc
from snman import *

PERIMETER = 'workshop_birchstrasse'
#PERIMETER = 'workshop_downtown'

data_directory = os.path.join('C:',os.sep,'Users','lballo','polybox','COMMUNICATION','2024-09-04 SNMan workshop','gis','snman_workshop_package')
inputs_path = os.path.join(data_directory, 'inputs')
process_path = os.path.join(data_directory, 'process', PERIMETER)
export_path = os.path.join(data_directory, 'outputs', PERIMETER)

CRS_internal = 2056      # for Zurich

# %% [markdown]
# Loading data
# ------------
# Loads the prepared simplified street graph, as well as other datasets such as perimeters, rebuilding regions and measurement regions

# %%
print('Load street graph')
G = snman.io.load_street_graph(
    os.path.join(process_path, 'street_graph_edges.gpkg'),
    os.path.join(process_path, 'street_graph_nodes.gpkg'),
    crs=CRS_internal
)

street_graph.organize_edge_directions(G)
# Out:
# Load street graph

# %%
print('Load rebuilding regions')
# Polygons that define which streets will be reorganized
rebuilding_regions_gdf = snman.io.load_rebuilding_regions(
    os.path.join(inputs_path, 'rebuilding_regions', 'rebuilding_regions.gpkg'),
    only_active=True,
    #projects=['workshop_birchstrasse_main'],
    crs=CRS_internal
)

if 1:
    print('Load access needs')
    access_needs = snman.io.load_access_needs(
        os.path.join(inputs_path, 'switzerland', 'zurich', 'statpop', 'statpop17_zurich_city_agg_on_buildings.gpkg'),
        CRS_internal
    )
    access_needs['parking_spots_needed'] = access_needs['residents'] / 60
    
if 1:
    print('Load lane edits')
    lane_edits = snman.io.load_lane_edits(
        os.path.join(inputs_path, 'lane_edits', 'lane_edits.gpkg')
    )
    snman.enrichment.match_lane_edits(
        G, lane_edits, lanes_key=KEY_FORCED_GIVEN_LANES_DESCRIPTION,
        max_dist=200, max_dist_init=500, max_lattice_width=5,
    )
    
if 1:
    print('Load hierarchy edits')
    hierarchy_edits = snman.io.load_hierarchy_edits(
        os.path.join(inputs_path, 'hierarchy_edits', 'hierarchy_edits.gpkg')
    )
    snman.enrichment.match_hierarchy_edits(
        G, hierarchy_edits,
        max_dist=200, max_dist_init=500, max_lattice_width=5,
    )
# Out:
# Load rebuilding regions
# Load access needs
# Load lane edits
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 20
#      18 if 1:
#      19     print('Load lane edits')
# ---> 20     lane_edits = snman.io.load_lane_edits(
#      21         os.path.join(inputs_path, 'lane_edits', 'lane_edits.gpkg')
#      22     )
#      23     snman.enrichment.match_lane_edits(
#      24         G, lane_edits, lanes_key=KEY_FORCED_GIVEN_LANES_DESCRIPTION,
#      25         max_dist=200, max_dist_init=500, max_lattice_width=5,
#      26     )
#      28 if 1:
#
# File ~\polybox\GIT\github\snman\snman\io.py:437, in load_lane_edits(path, lane_columns, crs)
#     435 # convert strings to SpaceAllocation
#     436 for column in lane_columns:
# --> 437     lane_edits[column] = lane_edits[column].apply(
#     438         lambda x: space_allocation.space_allocation_from_string(x)
#     439     )
#     441 return lane_edits
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\series.py:4917, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
# -> 4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
#    4924     ).apply()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# File ~\polybox\GIT\github\snman\snman\io.py:438, in load_lane_edits.<locals>.<lambda>(x)
#     435 # convert strings to SpaceAllocation
#     436 for column in lane_columns:
#     437     lane_edits[column] = lane_edits[column].apply(
# --> 438         lambda x: space_allocation.space_allocation_from_string(x)
#     439     )
#     441 return lane_edits
#
# File ~\polybox\GIT\github\snman\snman\space_allocation.py:1078, in space_allocation_from_string(sa_string)
#    1075     return
#    1077 lane_strings = sa_string.split(' | ')
# -> 1078 lanes = [
#    1079     Lane(s[0], s[1], status=s[2], width=utils.safe_float(s[3:])) if len(s) > 2
#    1080     else Lane(s[0], s[1]) if len(s) == 2 # fallback for old lane format
#    1081     else None
#    1082     for s in lane_strings
#    1083 ]
#    1084 return SpaceAllocation(lanes)
#
# File ~\polybox\GIT\github\snman\snman\space_allocation.py:1080, in <listcomp>(.0)
#    1075     return
#    1077 lane_strings = sa_string.split(' | ')
#    1078 lanes = [
#    1079     Lane(s[0], s[1], status=s[2], width=utils.safe_float(s[3:])) if len(s) > 2
# -> 1080     else Lane(s[0], s[1]) if len(s) == 2 # fallback for old lane format
#    1081     else None
#    1082     for s in lane_strings
#    1083 ]
#    1084 return SpaceAllocation(lanes)
#
# File ~\polybox\GIT\github\snman\snman\space_allocation.py:1116, in Lane.__init__(self, lanetype, direction, status, width)
#    1114     self.width = width
#    1115 else:
# -> 1116     self.set_default_width()
#    1117 self.valid = True
#
# File ~\polybox\GIT\github\snman\snman\space_allocation.py:1129, in Lane.set_default_width(self)
#    1128 def set_default_width(self):
# -> 1129     self.width = LANE_TYPES[self.lanetype + self.direction]['width']
#
# KeyError: 'L/'

# %%
from snman.rebuilding import *

HLAs = multi_rebuild_regions(
    G, rebuilding_regions_gdf, access_needs,
    save_steps_path=os.path.join(export_path, 'steps'),
    save_steps_scaling_factor=4,
    gravity_iterations=10,
)
HLAs = list(filter(lambda HLA: HLA is not None, HLAs))
# Out:
# truncating street graph
# done truncating
# GIVEN LANES
# REMOVE PARKING
# iteration 1
# REMOVE CAR LANES
# iteration 1
# fixed (0, 343, '0-343-0-0')
# iteration 2
# [343, 0, '0-343-0-0a']
# fixed [343, 0, '0-343-0-0a']
# iteration 3
# fixed (902, 137, '137-902-0-0')
# iteration 4
# [137, 902, '137-902-0-0a']
# fixed [137, 902, '137-902-0-0a']
# iteration 5
# fixed (45, 97, '45-97-0-0')
# iteration 6
# [97, 45, '45-97-0-0a']
# fixed [97, 45, '45-97-0-0a']
# iteration 7
# fixed (46, 779, '46-779-0-0')
# iteration 8
# [779, 46, '46-779-0-0a']
# fixed [779, 46, '46-779-0-0a']
# iteration 9
# fixed (343, 223, '223-343-0-0')
# iteration 10
# fixed (137, 952, '137-952-0-0')
# iteration 11
# [952, 137, '137-952-0-0a']
# fixed [952, 137, '137-952-0-0a']
# iteration 12
# fixed (97, 98, '97-98-0-0')
# iteration 13
# fixed (779, 753, '753-779-0-0')
# iteration 14
# [753, 779, '753-779-0-0a']
# fixed [753, 779, '753-779-0-0a']
# iteration 15
# [223, 343, '223-343-0-0a']
# fixed [223, 343, '223-343-0-0a']
# iteration 16
# [98, 97, '97-98-0-0a']
# fixed [98, 97, '97-98-0-0a']
# iteration 17
# fixed (952, 411, '411-952-0-0')
# iteration 18
# [411, 952, '411-952-0-0a']
# fixed [411, 952, '411-952-0-0a']
# iteration 19
# fixed (65, 753, '65-753-0-0')
# iteration 20
# [753, 65, '65-753-0-0a']
# fixed [753, 65, '65-753-0-0a']
# iteration 21
# fixed (223, 344, '223-344-0-0')
# iteration 22
# [344, 223, '223-344-0-0a']
# fixed [344, 223, '223-344-0-0a']
# iteration 23
# fixed (98, 99, '98-99-0-0')
# iteration 24
# [99, 98, '98-99-0-0a']
# fixed [99, 98, '98-99-0-0a']
# iteration 25
# fixed (411, 111, '111-411-0-0')
# iteration 26
# fixed (65, 73, '65-73-0-0')
# iteration 27
# [73, 65, '65-73-0-0a']
# fixed [73, 65, '65-73-0-0a']
# iteration 28
# [111, 411, '111-411-0-0a']
# fixed [111, 411, '111-411-0-0a']
# iteration 29
# fixed (344, 118, '118-344-0-0')
# iteration 30
# fixed (99, 100, '99-100-0-0')
# iteration 31
# [100, 99, '99-100-0-0a']
# fixed [100, 99, '99-100-0-0a']
# iteration 32
# [118, 344, '118-344-0-0a']
# fixed [118, 344, '118-344-0-0a']
# iteration 33
# fixed (289, 100, '100-289-0-0')
# iteration 34
# fixed (73, 552, '73-552-0-0')
# iteration 35
# [552, 73, '73-552-0-0a']
# fixed [552, 73, '73-552-0-0a']
# iteration 36
# [100, 289, '100-289-0-0a']
# fixed [100, 289, '100-289-0-0a']
# iteration 37
# fixed (1000, 118, '118-1000-0-0')
# iteration 38
# [118, 1000, '118-1000-0-0a']
# fixed [118, 1000, '118-1000-0-0a']
# iteration 39
# fixed (289, 774, '289-774-0-0')
# iteration 40
# [774, 289, '289-774-0-0a']
# fixed [774, 289, '289-774-0-0a']
# iteration 41
# fixed (72, 552, '72-552-0-0')
# iteration 42
# [552, 72, '72-552-0-0a']
# fixed [552, 72, '72-552-0-0a']
# iteration 43
# fixed (117, 1000, '117-1000-0-0')
# iteration 44
# [1000, 117, '117-1000-0-0a']
# fixed [1000, 117, '117-1000-0-0a']
# iteration 45
# fixed (774, 111, '111-774-0-0')
# iteration 46
# [111, 774, '111-774-0-0a']
# fixed [111, 774, '111-774-0-0a']
# iteration 47
# fixed (72, 120, '72-120-0-0')
# iteration 48
# [120, 72, '72-120-0-0a']
# fixed [120, 72, '72-120-0-0a']
# iteration 49
# fixed (492, 117, '117-492-0-0')
# iteration 50
# [117, 492, '117-492-0-0a']
# fixed [117, 492, '117-492-0-0a']
# iteration 51
# fixed (286, 120, '120-286-0-0')
# iteration 52
# fixed (111, 492, '111-492-0-0')
# iteration 53
# [120, 286, '120-286-0-0a']
# fixed [120, 286, '120-286-0-0a']
# iteration 54
# [492, 111, '111-492-0-0a']
# fixed [492, 111, '111-492-0-0a']
# iteration 55
# fixed (139, 286, '139-286-0-0')
# iteration 56
# [286, 139, '139-286-0-0a']
# fixed [286, 139, '139-286-0-0a']
# iteration 57
# fixed (139, 287, '139-287-0-0')
# iteration 58
# [287, 139, '139-287-0-0a']
# fixed [287, 139, '139-287-0-0a']
# iteration 59
# fixed (287, 71, '71-287-0-0')
# iteration 60
# [71, 287, '71-287-0-0a']
# fixed [71, 287, '71-287-0-0a']
# iteration 61
# fixed (70, 71, '70-71-0-0')
# iteration 62
# [71, 70, '70-71-0-0a']
# fixed [71, 70, '70-71-0-0a']
# iteration 63
# fixed (70, 106, '70-106-0-0')
# iteration 64
# [106, 70, '70-106-0-0a']
# fixed [106, 70, '70-106-0-0a']
# iteration 65
# fixed (143, 106, '106-143-0-0')
# iteration 66
# [106, 143, '106-143-0-0a']
# fixed [106, 143, '106-143-0-0a']
# iteration 67
# fixed (68, 143, '68-143-0-0')
# iteration 68
# [143, 68, '68-143-0-0a']
# fixed [143, 68, '68-143-0-0a']
# iteration 69
# fixed (68, 111, '68-111-0-0')
# iteration 70
# [111, 68, '68-111-0-0a']
# fixed [111, 68, '68-111-0-0a']
# iteration 71
# REMOVE CYCLING LANES
# iteration 1
# removed (118, 1000, '118-1000-0-4')
# iteration 2
# removed (100, 289, '100-289-0-4')
# iteration 3
# removed (552, 73, '73-552-0-2')
# iteration 4
# removed (552, 72, '72-552-0-2')
# iteration 5
# removed (1000, 118, '118-1000-0-2')
# iteration 6
# removed (289, 100, '100-289-0-2')
# iteration 7
# removed (72, 552, '72-552-0-4')
# iteration 8
# removed (73, 552, '73-552-0-4')
# iteration 9
# removed (111, 774, '111-774-0-4')
# iteration 10
# removed (411, 952, '411-952-0-4')
# iteration 11
# removed (137, 902, '137-902-0-4')
# iteration 12
# removed (73, 65, '65-73-0-2')
# iteration 13
# removed (952, 137, '137-952-0-2')
# iteration 14
# removed (118, 1000, '118-1000-0-3')
# iteration 15
# removed (100, 289, '100-289-0-3')
# iteration 16
# removed (552, 72, '72-552-0-1')
# iteration 17
# removed (552, 73, '73-552-0-1')
# iteration 18
# removed (774, 111, '111-774-0-2')
# iteration 19
# removed (118, 344, '118-344-0-4')
# iteration 20
# removed (117, 492, '117-492-0-4')
# iteration 21
# removed (120, 286, '120-286-0-4')
# iteration 22
# removed (106, 143, '106-143-0-4')
# iteration 23
# removed (71, 287, '71-287-0-4')
# iteration 24
# removed (111, 411, '111-411-0-4')
# iteration 25
# removed (1000, 117, '117-1000-0-2')
# iteration 26
# removed (492, 111, '111-492-0-2')
# iteration 27
# removed (100, 99, '99-100-0-2')
# iteration 28
# removed (99, 98, '98-99-0-2')
# iteration 29
# removed (98, 97, '97-98-0-2')
# iteration 30
# removed (120, 72, '72-120-0-2')
# iteration 31
# removed (143, 68, '68-143-0-2')
# iteration 32
# removed (111, 68, '68-111-0-2')
# iteration 33
# removed (753, 65, '65-753-0-2')
# iteration 34
# removed (97, 45, '45-97-0-2')
# iteration 35
# removed (774, 289, '289-774-0-2')
# iteration 36
# removed (287, 139, '139-287-0-2')
# iteration 37
# removed (286, 139, '139-286-0-2')
# iteration 38
# removed (952, 411, '411-952-0-2')
# iteration 39
# removed (902, 137, '137-902-0-2')
# iteration 40
# removed (65, 73, '65-73-0-4')
# iteration 41
# removed (137, 952, '137-952-0-4')
# iteration 42
# removed (1000, 118, '118-1000-0-1')
# iteration 43
# removed (289, 100, '100-289-0-1')
# iteration 44
# removed (72, 552, '72-552-0-3')
# iteration 45
# removed (73, 552, '73-552-0-3')
# iteration 46
# removed (111, 774, '111-774-0-3')
# iteration 47
# removed (492, 117, '117-492-0-2')
# iteration 48
# removed (344, 118, '118-344-0-2')
# iteration 49
# removed (143, 106, '106-143-0-2')
# iteration 50
# removed (411, 111, '111-411-0-2')
# iteration 51
# removed (287, 71, '71-287-0-2')
# iteration 52
# removed (286, 120, '120-286-0-2')
# iteration 53
# removed (117, 1000, '117-1000-0-4')
# iteration 54
# removed (99, 100, '99-100-0-4')
# iteration 55
# removed (98, 99, '98-99-0-4')
# iteration 56
# removed (72, 120, '72-120-0-4')
# iteration 57
# removed (111, 492, '111-492-0-4')
# iteration 58
# removed (68, 143, '68-143-0-4')
# iteration 59
# removed (68, 111, '68-111-0-4')
# iteration 60
# removed (65, 753, '65-753-0-4')
# iteration 61
# removed (97, 98, '97-98-0-4')
# iteration 62
# removed (45, 97, '45-97-0-4')
# iteration 63
# removed (289, 774, '289-774-0-4')
# iteration 64
# removed (139, 287, '139-287-0-4')
# iteration 65
# removed (139, 286, '139-286-0-4')
# iteration 66
# removed (71, 70, '70-71-0-2')
# iteration 67
# removed (137, 902, '137-902-0-3')
# iteration 68
# removed (411, 952, '411-952-0-3')
# iteration 69
# removed (952, 137, '137-952-0-1')
# iteration 70
# removed (73, 65, '65-73-0-1')
# iteration 71
# MERGE TRANSIT AND CAR LANES
# iteration 1
# ADJUST WIDTH OF LANES
# (0, 343, 0) 5.800000000000001
# (0, 343, 0) 5.800000000000001
# (0, 343, 0) 5.800000000000001
# (0, 343, 0) 5.800000000000001
# (137, 902, 0) 0.7000000000000002
# (137, 952, 0) 0.7000000000000002
# (139, 286, 0) 0.40000000000000036
# (139, 286, 0) 0.40000000000000036
# (139, 287, 0) 0.40000000000000036
# (139, 287, 0) 0.40000000000000036
# (411, 952, 0) 0.7000000000000002
# (289, 774, 0) 0.40000000000000036
# (289, 774, 0) 0.40000000000000036
# (45, 97, 0) 0.40000000000000036
# (45, 97, 0) 0.40000000000000036
# (46, 779, 0) 3.8000000000000007
# (46, 779, 0) 3.8000000000000007
# (46, 779, 0) 3.8000000000000007
# (46, 779, 0) 3.8000000000000007
# (65, 73, 0) 0.7000000000000002
# (65, 753, 0) 0.40000000000000036
# (65, 753, 0) 0.40000000000000036
# (68, 111, 0) 0.40000000000000036
# (68, 111, 0) 0.40000000000000036
# (68, 143, 0) 0.40000000000000036
# (68, 143, 0) 0.40000000000000036
# (70, 71, 0) 0.6000000000000014
# (70, 71, 0) 0.6000000000000014
# (70, 71, 0) 0.6000000000000014
# (70, 106, 0) 0.8000000000000007
# (70, 106, 0) 0.8000000000000007
# (70, 106, 0) 0.8000000000000007
# (70, 106, 0) 0.8000000000000007
# (71, 287, 0) 0.40000000000000036
# (71, 287, 0) 0.40000000000000036
# (72, 120, 0) 0.40000000000000036
# (72, 120, 0) 0.40000000000000036
# (223, 343, 0) 0.7999999999999989
# (223, 343, 0) 0.7999999999999989
# (223, 343, 0) 0.7999999999999989
# (223, 343, 0) 0.7999999999999989
# (223, 344, 0) 0.8000000000000007
# (223, 344, 0) 0.8000000000000007
# (223, 344, 0) 0.8000000000000007
# (223, 344, 0) 0.8000000000000007
# (97, 98, 0) 0.40000000000000036
# (97, 98, 0) 0.40000000000000036
# (98, 99, 0) 0.40000000000000036
# (98, 99, 0) 0.40000000000000036
# (99, 100, 0) 0.40000000000000036
# (99, 100, 0) 0.40000000000000036
# (106, 143, 0) 0.40000000000000036
# (106, 143, 0) 0.40000000000000036
# (111, 411, 0) 0.40000000000000036
# (111, 411, 0) 0.40000000000000036
# (111, 492, 0) 0.40000000000000036
# (111, 492, 0) 0.40000000000000036
# (111, 774, 0) 0.20000000000000018
# (753, 779, 0) 0.7999999999999989
# (753, 779, 0) 0.7999999999999989
# (753, 779, 0) 0.7999999999999989
# (753, 779, 0) 0.7999999999999989
# (117, 492, 0) 0.40000000000000036
# (117, 492, 0) 0.40000000000000036
# (117, 1000, 0) 0.40000000000000036
# (117, 1000, 0) 0.40000000000000036
# (118, 344, 0) 0.40000000000000036
# (118, 344, 0) 0.40000000000000036
# (120, 286, 0) 0.40000000000000036
# (120, 286, 0) 0.40000000000000036
# (0, 1070, 0) 7.5
# (0, 1070, 0) 7.5
# (2, 266, 0) 5.0
# (2, 266, 0) 5.0
# (2, 902, 0) 9.0
# (2, 902, 0) 9.0
# (260, 437, 0) 3.0
# (260, 437, 0) 3.0
# (260, 1044, 0) 5.0
# (260, 1044, 0) 5.0
# (902, 1073, 0) 7.5
# (902, 1073, 0) 7.5
# (266, 1042, 0) 5.0
# (266, 1042, 0) 5.0
# (1042, 1043, 0) 5.0
# (1042, 1043, 0) 5.0
# (1043, 1044, 0) 5.0
# (1043, 1044, 0) 5.0
# (674, 1063, 0) 10.0
# (674, 1063, 0) 10.0
# (45, 1063, 0) 10.0
# (45, 1063, 0) 10.0
# (46, 360, 0) 6.0
# (46, 360, 0) 6.0
# (1070, 1071, 0) 7.5
# (1070, 1071, 0) 7.5
# (1072, 1073, 0) 7.5
# (1072, 1073, 0) 7.5
# (1071, 1072, 0) 7.5
# (1071, 1072, 0) 7.5
# (358, 437, 0) 3.0
# (358, 437, 0) 3.0
# (358, 498, 0) 3.0
# (358, 498, 0) 3.0
# (360, 674, 0) 8.0
# (360, 674, 0) 8.0
# (361, 498, 0) 3.0
# (361, 498, 0) 3.0
# removed (343, 0, '0-343-0-2')
# removed (0, 343, '0-343-0-4')
# removed (779, 46, '46-779-0-2')
# removed (46, 779, '46-779-0-4')
# removed (70, 71, '70-71-0-4')
# removed (106, 70, '70-106-0-2')
# removed (70, 106, '70-106-0-4')
# removed (343, 223, '223-343-0-2')
# removed (223, 343, '223-343-0-4')
# removed (344, 223, '223-344-0-2')
# removed (223, 344, '223-344-0-4')
# removed (779, 753, '753-779-0-2')
# removed (753, 779, '753-779-0-4')
# truncating street graph
# done truncating
# GIVEN LANES
# REMOVE PARKING
# iteration 1
# iteration 2
# iteration 3
# iteration 4
# iteration 5
# iteration 6
# iteration 7
# iteration 8
# iteration 9
# iteration 10
# iteration 11
# iteration 12
# iteration 13
# iteration 14
# iteration 15
# iteration 16
# iteration 17
# iteration 18
# iteration 19
# iteration 20
# iteration 21
# iteration 22
# iteration 23
# iteration 24
# iteration 25
# iteration 26
# iteration 27
# iteration 28
# iteration 29
# iteration 30
# iteration 31
# iteration 32
# iteration 33
# iteration 34
# iteration 35
# iteration 36
# iteration 37
# iteration 38
# iteration 39
# iteration 40
# iteration 41
# iteration 42
# iteration 43
# iteration 44
# iteration 45
# iteration 46
# iteration 47
# iteration 48
# iteration 49
# iteration 50
# iteration 51
# iteration 52
# iteration 53
# iteration 54
# iteration 55
# iteration 56
# iteration 57
# iteration 58
# iteration 59
# iteration 60
# iteration 61
# iteration 62
# iteration 63
# iteration 64
# iteration 65
# iteration 66
# iteration 67
# iteration 68
# iteration 69
# iteration 70
# iteration 71
# iteration 72
# iteration 73
# iteration 74
# iteration 75
# iteration 76
# iteration 77
# iteration 78
# iteration 79
# iteration 80
# iteration 81
# iteration 82
# iteration 83
# iteration 84
# iteration 85
# iteration 86
# REMOVE CAR LANES
# iteration 1
# removed (67, 100, '67-100-0-0')
# iteration 2
# fixed (100, 67, '67-100-0-0')
# iteration 3
# removed (67, 66, '66-67-0-0')
# iteration 4
# removed (102, 66, '66-102-0-0')
# iteration 5
# removed (262, 289, '262-289-0-0')
# iteration 6
# removed (505, 100, '100-505-0-0')
# iteration 7
# removed (261, 774, '261-774-0-0')
# iteration 8
# removed (264, 952, '264-952-0-0')
# iteration 9
# fixed (265, 137, '137-265-0-0')
# iteration 10
# removed (264, 265, '264-265-0-0')
# iteration 11
# fixed (1060, 265, '265-1060-0-0')
# iteration 12
# fixed (773, 1059, '773-1059-0-0')
# iteration 13
# fixed (1059, 1060, '1059-1060-0-0')
# iteration 14
# removed (95, 688, '95-688-0-0')
# iteration 15
# removed (65, 101, '65-101-0-0')
# iteration 16
# fixed (263, 773, '263-773-0-0')
# iteration 17
# fixed (806, 138, '138-806-0-0')
# iteration 18
# fixed (67, 806, '67-806-0-0')
# iteration 19
# removed (259, 773, '259-773-0-0')
# iteration 20
# fixed (262, 263, '262-263-0-0')
# iteration 21
# removed (261, 262, '261-262-0-0')
# iteration 22
# fixed (410, 99, '99-410-0-0')
# iteration 23
# removed (66, 102, '66-102-0-0')
# iteration 24
# removed (138, 139, '138-139-0-0')
# iteration 25
# fixed (138, 577, '138-577-0-0')
# iteration 26
# removed (577, 120, '120-577-0-0')
# iteration 27
# removed (578, 72, '72-578-0-0')
# iteration 28
# fixed (102, 551, '102-551-0-0')
# iteration 29
# removed (551, 552, '551-552-0-0')
# iteration 30
# fixed (95, 73, '73-95-0-0')
# iteration 31
# fixed (551, 95, '95-551-0-0')
# iteration 32
# fixed (578, 102, '102-578-0-0')
# iteration 33
# fixed (577, 578, '577-578-0-0')
# iteration 34
# fixed (101, 688, '101-688-0-0')
# iteration 35
# removed (688, 95, '95-688-0-0')
# iteration 36
# removed (101, 65, '65-101-0-0')
# iteration 37
# removed (655, 66, '66-655-0-0')
# iteration 38
# removed (289, 262, '262-289-0-0')
# iteration 39
# removed (264, 263, '263-264-0-0')
# iteration 40
# [137, 265, '137-265-0-0a']
# fixed [137, 265, '137-265-0-0a']
# iteration 41
# [265, 1060, '265-1060-0-0a']
# fixed [265, 1060, '265-1060-0-0a']
# iteration 42
# removed (100, 505, '100-505-0-0')
# iteration 43
# [1060, 1059, '1059-1060-0-0a']
# fixed [1060, 1059, '1059-1060-0-0a']
# iteration 44
# [1059, 773, '773-1059-0-0a']
# fixed [1059, 773, '773-1059-0-0a']
# iteration 45
# removed (773, 259, '259-773-0-0')
# iteration 46
# [99, 410, '99-410-0-0a']
# fixed [99, 410, '99-410-0-0a']
# iteration 47
# removed (554, 101, '101-554-0-0')
# iteration 48
# fixed (142, 143, '142-143-0-0')
# iteration 49
# removed (700, 287, '287-700-0-0')
# iteration 50
# removed (225, 952, '225-952-0-0')
# iteration 51
# fixed (224, 223, '223-224-0-0')
# iteration 52
# removed (287, 700, '287-700-0-0')
# iteration 53
# removed (225, 224, '224-225-0-0')
# iteration 54
# [143, 142, '142-143-0-0a']
# fixed [143, 142, '142-143-0-0a']
# iteration 55
# removed (66, 655, '66-655-0-0')
# iteration 56
# removed (101, 554, '101-554-0-0')
# iteration 57
# [688, 101, '101-688-0-0a']
# fixed [688, 101, '101-688-0-0a']
# iteration 58
# [773, 263, '263-773-0-0a']
# fixed [773, 263, '263-773-0-0a']
# iteration 59
# removed (506, 410, '410-506-0-0')
# iteration 60
# fixed (1066, 410, '410-1066-0-0')
# iteration 61
# fixed (506, 1066, '506-1066-0-0')
# iteration 62
# removed (66, 67, '66-67-0-0')
# iteration 63
# fixed (410, 506, '410-506-0-0')
# iteration 64
# removed (774, 261, '261-774-0-0')
# iteration 65
# [263, 262, '262-263-0-0a']
# fixed [263, 262, '262-263-0-0a']
# iteration 66
# removed (262, 261, '261-262-0-0')
# iteration 67
# fixed (369, 362, '362-369-0-0')
# iteration 68
# [362, 369, '362-369-0-0a']
# fixed [362, 369, '362-369-0-0a']
# iteration 69
# fixed (365, 362, '362-365-0-0')
# iteration 70
# [362, 365, '362-365-0-0a']
# fixed [362, 365, '362-365-0-0a']
# iteration 71
# fixed (136, 369, '136-369-0-0')
# iteration 72
# [369, 136, '136-369-0-0a']
# fixed [369, 136, '136-369-0-0a']
# iteration 73
# fixed (135, 136, '135-136-0-0')
# iteration 74
# [136, 135, '135-136-0-0a']
# fixed [136, 135, '135-136-0-0a']
# iteration 75
# removed (365, 364, '364-365-0-0')
# iteration 76
# removed (364, 365, '364-365-0-0')
# iteration 77
# [223, 224, '223-224-0-0a']
# fixed [223, 224, '223-224-0-0a']
# iteration 78
# removed (266, 265, '265-266-0-0')
# iteration 79
# removed (141, 142, '141-142-0-0')
# iteration 80
# fixed (92, 779, '92-779-0-0')
# iteration 81
# removed (805, 142, '142-805-0-0')
# iteration 82
# fixed (345, 344, '344-345-0-0')
# iteration 83
# removed (358, 506, '358-506-0-0')
# iteration 84
# removed (760, 411, '411-760-0-0')
# iteration 85
# removed (689, 688, '688-689-0-0')
# iteration 86
# removed (688, 689, '688-689-0-0')
# iteration 87
# removed (411, 760, '411-760-0-0')
# iteration 88
# removed (265, 266, '265-266-0-0')
# iteration 89
# removed (142, 141, '141-142-0-0')
# iteration 90
# removed (142, 805, '142-805-0-0')
# iteration 91
# removed (506, 358, '358-506-0-0')
# iteration 92
# [779, 92, '92-779-0-0a']
# fixed [779, 92, '92-779-0-0a']
# iteration 93
# [344, 345, '344-345-0-0a']
# fixed [344, 345, '344-345-0-0a']
# iteration 94
# removed (410, 1066, '410-1066-0-0')
# iteration 95
# removed (952, 225, '225-952-0-0')
# iteration 96
# removed (224, 225, '224-225-0-0')
# iteration 97
# removed (952, 264, '264-952-0-0')
# iteration 98
# removed (265, 264, '264-265-0-0')
# iteration 99
# removed (263, 264, '263-264-0-0')
# iteration 100
# removed (120, 577, '120-577-0-0')
# iteration 101
# removed (139, 138, '138-139-0-0')
# iteration 102
# removed (72, 578, '72-578-0-0')
# iteration 103
# removed (551, 102, '102-551-0-0')
# iteration 104
# fixed (135, 257, '135-257-0-0')
# iteration 105
# [257, 135, '135-257-0-0a']
# fixed [257, 135, '135-257-0-0a']
# iteration 106
# fixed (359, 365, '359-365-0-0')
# iteration 107
# [365, 359, '359-365-0-0a']
# fixed [365, 359, '359-365-0-0a']
# iteration 108
# removed (136, 495, '136-495-0-0')
# iteration 109
# removed (495, 136, '136-495-0-0')
# iteration 110
# removed (73, 95, '73-95-0-0')
# iteration 111
# removed (552, 551, '551-552-0-0')
# iteration 112
# removed (361, 362, '361-362-0-0')
# iteration 113
# fixed (360, 359, '359-360-0-0')
# iteration 114
# removed (714, 135, '135-714-0-0')
# iteration 115
# removed (258, 257, '257-258-0-0')
# iteration 116
# fixed (1057, 257, '257-1057-0-0')
# iteration 117
# removed (674, 359, '359-674-0-0')
# iteration 118
# removed (368, 369, '368-369-0-0')
# iteration 119
# removed (577, 138, '138-577-0-0')
# iteration 120
# removed (135, 714, '135-714-0-0')
# iteration 121
# removed (257, 258, '257-258-0-0')
# iteration 122
# removed (369, 368, '368-369-0-0')
# iteration 123
# removed (359, 674, '359-674-0-0')
# iteration 124
# removed (362, 361, '361-362-0-0')
# iteration 125
# [257, 1057, '257-1057-0-0a']
# fixed [257, 1057, '257-1057-0-0a']
# iteration 126
# [359, 360, '359-360-0-0a']
# fixed [359, 360, '359-360-0-0a']
# iteration 127
# removed (363, 367, '363-367-0-0')
# iteration 128
# removed (363, 364, '363-364-0-0')
# iteration 129
# removed (366, 367, '366-367-0-0')
# iteration 130
# removed (259, 260, '259-260-0-0')
# iteration 131
# removed (259, 619, '259-619-0-0')
# iteration 132
# removed (505, 619, '505-619-0-0')
# iteration 133
# removed (366, 409, '366-409-0-0')
# iteration 134
# removed (437, 619, '437-619-0-0')
# iteration 135
# removed (102, 578, '102-578-0-0')
# iteration 136
# removed (806, 67, '67-806-0-0')
# iteration 137
# removed (259, 505, '259-505-0-0')
# iteration 138
# removed (700, 702, '700-702-0-0')
# iteration 139
# removed (364, 367, '364-367-0-0')
# iteration 140
# removed (363, 366, '363-366-0-0')
# iteration 141
# removed (366, 363, '363-366-0-0')
# iteration 142
# removed (702, 700, '700-702-0-0')
# iteration 143
# fixed (2, 783, '2-783-0-0')
# iteration 144
# [783, 2, '2-783-0-0a']
# fixed [783, 2, '2-783-0-0a']
# iteration 145
# removed (655, 554, '554-655-0-0')
# iteration 146
# removed (655, 1067, '655-1067-0-0')
# iteration 147
# removed (578, 577, '577-578-0-0')
# iteration 148
# removed (95, 551, '95-551-0-0')
# iteration 149
# removed (505, 259, '259-505-0-0')
# iteration 150
# removed (554, 655, '554-655-0-0')
# iteration 151
# removed (554, 1067, '554-1067-0-0')
# iteration 152
# removed (495, 496, '495-496-0-0')
# iteration 153
# removed (138, 806, '138-806-0-0')
# iteration 154
# removed (260, 259, '259-260-0-0')
# iteration 155
# removed (619, 259, '259-619-0-0')
# iteration 156
# removed (619, 437, '437-619-0-0')
# iteration 157
# removed (619, 505, '505-619-0-0')
# iteration 158
# removed (261, 953, '261-953-0-0')
# iteration 159
# removed (953, 261, '261-953-0-0')
# iteration 160
# removed (498, 497, '497-498-0-0')
# iteration 161
# removed (364, 363, '363-364-0-0')
# iteration 162
# removed (367, 363, '363-367-0-0')
# iteration 163
# removed (367, 364, '364-367-0-0')
# iteration 164
# removed (367, 366, '366-367-0-0')
# iteration 165
# removed (409, 366, '366-409-0-0')
# iteration 166
# removed (1066, 506, '506-1066-0-0')
# iteration 167
# removed (496, 495, '495-496-0-0')
# iteration 168
# removed (497, 498, '497-498-0-0')
# iteration 169
# removed (1067, 554, '554-1067-0-0')
# iteration 170
# removed (1067, 655, '655-1067-0-0')
# iteration 171
# removed (702, 807, '702-807-0-0')
# iteration 172
# removed (807, 702, '702-807-0-0')
# iteration 173
# REMOVE CYCLING LANES
# iteration 1
# removed (345, 344, '344-345-0-2')
# iteration 2
# removed (224, 223, '223-224-0-2')
# iteration 3
# removed (223, 224, '223-224-0-4')
# iteration 4
# removed (344, 345, '344-345-0-4')
# iteration 5
# removed (359, 360, '359-360-0-4')
# iteration 6
# removed (362, 369, '362-369-0-4')
# iteration 7
# removed (362, 365, '362-365-0-4')
# iteration 8
# removed (263, 262, '262-263-0-2')
# iteration 9
# removed (142, 143, '142-143-0-4')
# iteration 10
# removed (265, 137, '137-265-0-2')
# iteration 11
# removed (136, 135, '135-136-0-2')
# iteration 12
# removed (410, 99, '99-410-0-2')
# iteration 13
# removed (688, 101, '101-688-0-2')
# iteration 14
# removed (783, 2, '2-783-0-2')
# iteration 15
# removed (365, 359, '359-365-0-2')
# iteration 16
# removed (263, 773, '263-773-0-4')
# iteration 17
# removed (1060, 265, '265-1060-0-2')
# iteration 18
# removed (1059, 1060, '1059-1060-0-4')
# iteration 19
# removed (1059, 773, '773-1059-0-2')
# iteration 20
# removed (344, 345, '344-345-0-3')
# iteration 21
# removed (224, 223, '223-224-0-1')
# iteration 22
# removed (360, 359, '359-360-0-2')
# iteration 23
# removed (365, 362, '362-365-0-2')
# iteration 24
# removed (262, 263, '262-263-0-4')
# iteration 25
# removed (137, 265, '137-265-0-4')
# iteration 26
# removed (369, 362, '362-369-0-2')
# iteration 27
# removed (135, 136, '135-136-0-4')
# iteration 28
# removed (99, 410, '99-410-0-4')
# iteration 29
# removed (143, 142, '142-143-0-2')
# iteration 30
# removed (101, 688, '101-688-0-4')
# iteration 31
# removed (2, 783, '2-783-0-4')
# iteration 32
# removed (359, 365, '359-365-0-4')
# iteration 33
# removed (773, 263, '263-773-0-2')
# iteration 34
# removed (265, 1060, '265-1060-0-4')
# iteration 35
# removed (1060, 1059, '1059-1060-0-2')
# iteration 36
# removed (773, 1059, '773-1059-0-4')
# iteration 37
# removed (345, 344, '344-345-0-1')
# iteration 38
# removed (223, 224, '223-224-0-3')
# iteration 39
# removed (369, 136, '136-369-0-2')
# iteration 40
# removed (257, 135, '135-257-0-2')
# iteration 41
# removed (359, 360, '359-360-0-3')
# iteration 42
# removed (265, 137, '137-265-0-1')
# iteration 43
# removed (263, 773, '263-773-0-3')
# iteration 44
# removed (362, 369, '362-369-0-3')
# iteration 45
# removed (365, 362, '362-365-0-1')
# iteration 46
# removed (410, 99, '99-410-0-1')
# iteration 47
# removed (135, 136, '135-136-0-3')
# iteration 48
# removed (688, 101, '101-688-0-1')
# iteration 49
# removed (359, 365, '359-365-0-3')
# iteration 50
# removed (263, 262, '262-263-0-1')
# iteration 51
# removed (142, 143, '142-143-0-3')
# iteration 52
# removed (783, 2, '2-783-0-1')
# iteration 53
# removed (506, 410, '410-506-0-2')
# iteration 54
# removed (578, 102, '102-578-0-2')
# iteration 55
# removed (100, 67, '67-100-0-2')
# iteration 56
# removed (1066, 506, '506-1066-0-2')
# iteration 57
# removed (1066, 410, '410-1066-0-2')
# iteration 58
# removed (138, 806, '138-806-0-4')
# iteration 59
# removed (138, 577, '138-577-0-4')
# iteration 60
# removed (577, 578, '577-578-0-4')
# iteration 61
# removed (806, 67, '67-806-0-2')
# iteration 62
# removed (1060, 265, '265-1060-0-1')
# iteration 63
# removed (1059, 1060, '1059-1060-0-3')
# iteration 64
# removed (1059, 773, '773-1059-0-1')
# iteration 65
# removed (136, 369, '136-369-0-4')
# iteration 66
# removed (135, 257, '135-257-0-4')
# iteration 67
# removed (360, 359, '359-360-0-1')
# iteration 68
# removed (1057, 257, '257-1057-0-2')
# iteration 69
# removed (137, 265, '137-265-0-3')
# iteration 70
# removed (136, 135, '135-136-0-1')
# iteration 71
# removed (101, 688, '101-688-0-3')
# iteration 72
# removed (262, 263, '262-263-0-3')
# iteration 73
# removed (143, 142, '142-143-0-1')
# iteration 74
# removed (2, 783, '2-783-0-3')
# iteration 75
# removed (773, 263, '263-773-0-1')
# iteration 76
# removed (369, 362, '362-369-0-1')
# iteration 77
# removed (362, 365, '362-365-0-3')
# iteration 78
# removed (99, 410, '99-410-0-3')
# iteration 79
# removed (365, 359, '359-365-0-1')
# iteration 80
# removed (410, 506, '410-506-0-4')
# iteration 81
# removed (102, 578, '102-578-0-4')
# iteration 82
# removed (67, 100, '67-100-0-4')
# iteration 83
# removed (506, 1066, '506-1066-0-4')
# iteration 84
# removed (577, 138, '138-577-0-2')
# iteration 85
# removed (410, 1066, '410-1066-0-4')
# iteration 86
# removed (578, 577, '577-578-0-2')
# iteration 87
# removed (806, 138, '138-806-0-2')
# iteration 88
# removed (67, 806, '67-806-0-4')
# iteration 89
# removed (265, 1060, '265-1060-0-3')
# iteration 90
# removed (1060, 1059, '1059-1060-0-1')
# iteration 91
# removed (773, 1059, '773-1059-0-3')
# iteration 92
# removed (674, 359, '359-674-0-2')
# iteration 93
# removed (264, 265, '264-265-0-4')
# iteration 94
# removed (264, 263, '263-264-0-2')
# iteration 95
# removed (554, 101, '101-554-0-2')
# iteration 96
# removed (257, 135, '135-257-0-1')
# iteration 97
# removed (369, 136, '136-369-0-1')
# iteration 98
# removed (257, 1057, '257-1057-0-4')
# iteration 99
# removed (551, 102, '102-551-0-2')
# iteration 100
# removed (551, 95, '95-551-0-2')
# iteration 101
# removed (95, 73, '73-95-0-2')
# iteration 102
# removed (806, 138, '138-806-0-1')
# iteration 103
# removed (100, 67, '67-100-0-1')
# iteration 104
# removed (67, 806, '67-806-0-3')
# iteration 105
# removed (1066, 506, '506-1066-0-1')
# iteration 106
# removed (1066, 410, '410-1066-0-1')
# iteration 107
# removed (410, 506, '410-506-0-3')
# iteration 108
# removed (577, 578, '577-578-0-3')
# iteration 109
# removed (138, 577, '138-577-0-3')
# iteration 110
# removed (578, 102, '102-578-0-1')
# iteration 111
# removed (359, 674, '359-674-0-4')
# iteration 112
# removed (263, 264, '263-264-0-4')
# iteration 113
# removed (265, 264, '264-265-0-2')
# iteration 114
# removed (101, 554, '101-554-0-4')
# iteration 115
# removed (135, 257, '135-257-0-3')
# iteration 116
# removed (136, 369, '136-369-0-3')
# iteration 117
# removed (807, 702, '702-807-0-2')
# iteration 118
# removed (702, 700, '700-702-0-2')
# iteration 119
# removed (689, 688, '688-689-0-2')
# iteration 120
# removed (1067, 655, '655-1067-0-2')
# iteration 121
# removed (1067, 554, '554-1067-0-2')
# iteration 122
# removed (496, 495, '495-496-0-2')
# iteration 123
# removed (760, 411, '411-760-0-2')
# iteration 124
# removed (409, 366, '366-409-0-2')
# iteration 125
# removed (367, 366, '366-367-0-2')
# iteration 126
# removed (367, 364, '364-367-0-2')
# iteration 127
# removed (367, 363, '363-367-0-2')
# iteration 128
# removed (366, 363, '363-366-0-2')
# iteration 129
# removed (364, 365, '364-365-0-4')
# iteration 130
# removed (364, 363, '363-364-0-2')
# iteration 131
# removed (700, 287, '287-700-0-2')
# iteration 132
# removed (264, 952, '264-952-0-4')
# iteration 133
# removed (953, 261, '261-953-0-2')
# iteration 134
# removed (262, 289, '262-289-0-4')
# iteration 135
# removed (262, 261, '261-262-0-2')
# iteration 136
# removed (437, 619, '437-619-0-4')
# iteration 137
# removed (773, 259, '259-773-0-2')
# iteration 138
# removed (619, 259, '259-619-0-2')
# iteration 139
# removed (258, 257, '257-258-0-2')
# iteration 140
# removed (225, 952, '225-952-0-4')
# iteration 141
# removed (225, 224, '224-225-0-2')
# iteration 142
# removed (805, 142, '142-805-0-2')
# iteration 143
# removed (139, 138, '138-139-0-2')
# iteration 144
# removed (265, 266, '265-266-0-4')
# iteration 145
# removed (714, 135, '135-714-0-2')
# iteration 146
# removed (577, 120, '120-577-0-2')
# iteration 147
# removed (578, 72, '72-578-0-2')
# iteration 148
# removed (102, 66, '66-102-0-2')
# iteration 149
# removed (257, 1057, '257-1057-0-3')
# iteration 150
# removed (95, 551, '95-551-0-4')
# iteration 151
# removed (102, 551, '102-551-0-4')
# iteration 152
# removed (73, 95, '73-95-0-4')
# iteration 153
# removed (362, 361, '361-362-0-2')
# iteration 154
# removed (142, 141, '141-142-0-2')
# iteration 155
# removed (554, 655, '554-655-0-4')
# iteration 156
# removed (67, 66, '66-67-0-2')
# iteration 157
# removed (101, 65, '65-101-0-2')
# iteration 158
# MERGE TRANSIT AND CAR LANES
# iteration 1
# ADJUST WIDTH OF LANES
# (65, 101, 0) 1.0999999999999996
# (65, 101, 0) 1.0999999999999996
# (65, 101, 0) 1.0999999999999996
# (66, 67, 0) 1.0999999999999996
# (66, 67, 0) 1.0999999999999996
# (66, 67, 0) 1.0999999999999996
# (66, 102, 0) 0.5999999999999996
# (66, 102, 0) 0.5999999999999996
# (66, 102, 0) 0.5999999999999996
# (66, 655, 0) 1.2999999999999998
# (66, 655, 0) 1.2999999999999998
# (66, 655, 0) 1.2999999999999998
# (66, 655, 0) 1.2999999999999998
# (67, 100, 0) 0.20000000000000018
# (67, 141, 0) 2.0
# (67, 141, 0) 2.0
# (67, 806, 0) 0.20000000000000018
# (68, 141, 0) 2.0
# (68, 141, 0) 2.0
# (72, 578, 0) 0.5999999999999996
# (72, 578, 0) 0.5999999999999996
# (72, 578, 0) 0.5999999999999996
# (73, 95, 0) 0.9000000000000004
# (73, 95, 0) 0.9000000000000004
# (92, 779, 0) 1.799999999999999
# (92, 779, 0) 1.799999999999999
# (92, 779, 0) 1.799999999999999
# (92, 779, 0) 1.799999999999999
# (95, 551, 0) 0.9000000000000004
# (95, 551, 0) 0.9000000000000004
# (95, 688, 0) 1.2999999999999998
# (95, 688, 0) 1.2999999999999998
# (95, 688, 0) 1.2999999999999998
# (95, 688, 0) 1.2999999999999998
# (100, 505, 0) 1.2999999999999998
# (100, 505, 0) 1.2999999999999998
# (100, 505, 0) 1.2999999999999998
# (100, 505, 0) 1.2999999999999998
# (101, 554, 0) 0.3999999999999999
# (101, 554, 0) 0.3999999999999999
# (102, 551, 0) 0.9000000000000004
# (102, 551, 0) 0.9000000000000004
# (102, 578, 0) 0.20000000000000018
# (120, 577, 0) 0.5999999999999996
# (120, 577, 0) 0.5999999999999996
# (120, 577, 0) 0.5999999999999996
# (135, 714, 0) 0.5999999999999996
# (135, 714, 0) 0.5999999999999996
# (135, 714, 0) 0.5999999999999996
# (136, 495, 0) 1.2999999999999998
# (136, 495, 0) 1.2999999999999998
# (136, 495, 0) 1.2999999999999998
# (136, 495, 0) 1.2999999999999998
# (138, 139, 0) 0.5999999999999996
# (138, 139, 0) 0.5999999999999996
# (138, 139, 0) 0.5999999999999996
# (138, 577, 0) 0.20000000000000018
# (138, 806, 0) 0.20000000000000018
# (141, 142, 0) 1.0999999999999996
# (141, 142, 0) 1.0999999999999996
# (141, 142, 0) 1.0999999999999996
# (142, 805, 0) 0.5999999999999996
# (142, 805, 0) 0.5999999999999996
# (142, 805, 0) 0.5999999999999996
# (224, 225, 0) 0.5999999999999996
# (224, 225, 0) 0.5999999999999996
# (224, 225, 0) 0.5999999999999996
# (225, 952, 0) 0.5999999999999996
# (225, 952, 0) 0.5999999999999996
# (225, 952, 0) 0.5999999999999996
# (257, 258, 0) 0.5999999999999996
# (257, 258, 0) 0.5999999999999996
# (257, 258, 0) 0.5999999999999996
# (257, 1057, 0) 0.7000000000000002
# (259, 260, 0) 1.2999999999999998
# (259, 260, 0) 1.2999999999999998
# (259, 260, 0) 1.2999999999999998
# (259, 260, 0) 1.2999999999999998
# (259, 505, 0) 1.2999999999999998
# (259, 505, 0) 1.2999999999999998
# (259, 505, 0) 1.2999999999999998
# (259, 505, 0) 1.2999999999999998
# (259, 619, 0) 0.5999999999999996
# (259, 619, 0) 0.5999999999999996
# (259, 619, 0) 0.5999999999999996
# (259, 773, 0) 0.5999999999999996
# (259, 773, 0) 0.5999999999999996
# (259, 773, 0) 0.5999999999999996
# (261, 262, 0) 0.5999999999999996
# (261, 262, 0) 0.5999999999999996
# (261, 262, 0) 0.5999999999999996
# (261, 774, 0) 1.2999999999999998
# (261, 774, 0) 1.2999999999999998
# (261, 774, 0) 1.2999999999999998
# (261, 774, 0) 1.2999999999999998
# (261, 953, 0) 0.5999999999999996
# (261, 953, 0) 0.5999999999999996
# (261, 953, 0) 0.5999999999999996
# (262, 289, 0) 0.5999999999999996
# (262, 289, 0) 0.5999999999999996
# (262, 289, 0) 0.5999999999999996
# (263, 264, 0) 0.3999999999999999
# (263, 264, 0) 0.3999999999999999
# (264, 265, 0) 0.3999999999999999
# (264, 265, 0) 0.3999999999999999
# (264, 952, 0) 0.5999999999999996
# (264, 952, 0) 0.5999999999999996
# (264, 952, 0) 0.5999999999999996
# (265, 266, 0) 0.5999999999999996
# (265, 266, 0) 0.5999999999999996
# (265, 266, 0) 0.5999999999999996
# (287, 700, 0) 0.5999999999999996
# (287, 700, 0) 0.5999999999999996
# (287, 700, 0) 0.5999999999999996
# (358, 506, 0) 1.2999999999999998
# (358, 506, 0) 1.2999999999999998
# (358, 506, 0) 1.2999999999999998
# (358, 506, 0) 1.2999999999999998
# (359, 674, 0) 0.3999999999999999
# (359, 674, 0) 0.3999999999999999
# (361, 362, 0) 1.0999999999999996
# (361, 362, 0) 1.0999999999999996
# (361, 362, 0) 1.0999999999999996
# (363, 364, 0) 0.5999999999999996
# (363, 364, 0) 0.5999999999999996
# (363, 364, 0) 0.5999999999999996
# (363, 366, 0) 0.5999999999999996
# (363, 366, 0) 0.5999999999999996
# (363, 366, 0) 0.5999999999999996
# (363, 367, 0) 0.5999999999999996
# (363, 367, 0) 0.5999999999999996
# (363, 367, 0) 0.5999999999999996
# (364, 365, 0) 0.5999999999999996
# (364, 365, 0) 0.5999999999999996
# (364, 365, 0) 0.5999999999999996
# (364, 367, 0) 0.5999999999999996
# (364, 367, 0) 0.5999999999999996
# (364, 367, 0) 0.5999999999999996
# (366, 367, 0) 0.5999999999999996
# (366, 367, 0) 0.5999999999999996
# (366, 367, 0) 0.5999999999999996
# (366, 409, 0) 0.5999999999999996
# (366, 409, 0) 0.5999999999999996
# (366, 409, 0) 0.5999999999999996
# (368, 369, 0) 1.2999999999999998
# (368, 369, 0) 1.2999999999999998
# (368, 369, 0) 1.2999999999999998
# (368, 369, 0) 1.2999999999999998
# (410, 506, 0) 0.20000000000000018
# (410, 1066, 0) 0.20000000000000018
# (411, 760, 0) 0.5999999999999996
# (411, 760, 0) 0.5999999999999996
# (411, 760, 0) 0.5999999999999996
# (437, 619, 0) 0.5999999999999996
# (437, 619, 0) 0.5999999999999996
# (437, 619, 0) 0.5999999999999996
# (495, 496, 0) 0.5999999999999996
# (495, 496, 0) 0.5999999999999996
# (495, 496, 0) 0.5999999999999996
# (497, 498, 0) 0.7999999999999998
# (497, 498, 0) 0.7999999999999998
# (497, 498, 0) 0.7999999999999998
# (497, 498, 0) 0.7999999999999998
# (505, 619, 0) 1.2999999999999998
# (505, 619, 0) 1.2999999999999998
# (505, 619, 0) 1.2999999999999998
# (505, 619, 0) 1.2999999999999998
# (506, 1066, 0) 0.20000000000000018
# (551, 552, 0) 1.2999999999999998
# (551, 552, 0) 1.2999999999999998
# (551, 552, 0) 1.2999999999999998
# (551, 552, 0) 1.2999999999999998
# (554, 655, 0) 1.0999999999999996
# (554, 655, 0) 1.0999999999999996
# (554, 655, 0) 1.0999999999999996
# (554, 1067, 0) 0.5999999999999996
# (554, 1067, 0) 0.5999999999999996
# (554, 1067, 0) 0.5999999999999996
# (577, 578, 0) 0.20000000000000018
# (655, 1067, 0) 0.5999999999999996
# (655, 1067, 0) 0.5999999999999996
# (655, 1067, 0) 0.5999999999999996
# (688, 689, 0) 0.5999999999999996
# (688, 689, 0) 0.5999999999999996
# (688, 689, 0) 0.5999999999999996
# (700, 702, 0) 0.5999999999999996
# (700, 702, 0) 0.5999999999999996
# (700, 702, 0) 0.5999999999999996
# (702, 807, 0) 0.5999999999999996
# (702, 807, 0) 0.5999999999999996
# (702, 807, 0) 0.5999999999999996
# (2, 783, 0) -1.5
# (2, 783, 0) -1.5
# (2, 783, 0) -1.5
# (66, 98, 0) 0.5
# (66, 98, 0) 0.5
# (97, 101, 0) -1.5
# (97, 101, 0) -1.5
# (99, 410, 0) -1.5
# (99, 410, 0) -1.5
# (101, 688, 0) -1.5
# (101, 688, 0) -1.5
# (101, 688, 0) -1.5
# (135, 136, 0) -1.5
# (135, 136, 0) -1.5
# (135, 136, 0) -1.5
# (135, 257, 0) 0.5
# (135, 257, 0) 0.5
# (136, 369, 0) 0.5
# (136, 369, 0) 0.5
# (137, 265, 0) -1.5
# (137, 265, 0) -1.5
# (137, 265, 0) -1.5
# (142, 143, 0) -1.5
# (142, 143, 0) -1.5
# (142, 143, 0) -1.5
# (223, 224, 0) -3.5
# (223, 224, 0) -3.5
# (223, 224, 0) -3.5
# (262, 263, 0) -1.5
# (262, 263, 0) -1.5
# (262, 263, 0) -1.5
# (263, 773, 0) -1.5
# (263, 773, 0) -1.5
# (265, 1060, 0) -1.0
# (265, 1060, 0) -1.0
# (344, 345, 0) -3.5
# (344, 345, 0) -3.5
# (344, 345, 0) -3.5
# (359, 360, 0) -2.0
# (359, 360, 0) -2.0
# (359, 360, 0) -2.0
# (359, 365, 0) -1.5
# (359, 365, 0) -1.5
# (362, 365, 0) -1.5
# (362, 365, 0) -1.5
# (362, 369, 0) -1.5
# (362, 369, 0) -1.5
# (773, 1059, 0) -1.0
# (773, 1059, 0) -1.0
# (783, 1061, 0) 6.0
# (1055, 1056, 0) 6.0
# (1055, 1069, 0) 6.0
# (1056, 1057, 0) 6.0
# (1059, 1060, 0) -1.0
# (1059, 1060, 0) -1.0
# (1061, 1069, 0) 6.0
# removed (65, 101, '65-101-0-4')
# removed (66, 67, '66-67-0-4')
# removed (66, 102, '66-102-0-4')
# removed (655, 66, '66-655-0-2')
# removed (66, 655, '66-655-0-4')
# removed (72, 578, '72-578-0-4')
# removed (779, 92, '92-779-0-2')
# removed (92, 779, '92-779-0-4')
# removed (688, 95, '95-688-0-2')
# removed (95, 688, '95-688-0-4')
# removed (505, 100, '100-505-0-2')
# removed (100, 505, '100-505-0-4')
# removed (120, 577, '120-577-0-4')
# removed (135, 714, '135-714-0-4')
# removed (495, 136, '136-495-0-2')
# removed (136, 495, '136-495-0-4')
# removed (138, 139, '138-139-0-4')
# removed (141, 142, '141-142-0-4')
# removed (142, 805, '142-805-0-4')
# removed (224, 225, '224-225-0-4')
# removed (952, 225, '225-952-0-2')
# removed (257, 258, '257-258-0-4')
# removed (260, 259, '259-260-0-2')
# removed (259, 260, '259-260-0-4')
# removed (505, 259, '259-505-0-2')
# removed (259, 505, '259-505-0-4')
# removed (259, 619, '259-619-0-4')
# removed (259, 773, '259-773-0-4')
# removed (261, 262, '261-262-0-4')
# removed (774, 261, '261-774-0-2')
# removed (261, 774, '261-774-0-4')
# removed (261, 953, '261-953-0-4')
# removed (289, 262, '262-289-0-2')
# removed (952, 264, '264-952-0-2')
# removed (266, 265, '265-266-0-2')
# removed (287, 700, '287-700-0-4')
# removed (506, 358, '358-506-0-2')
# removed (358, 506, '358-506-0-4')
# removed (361, 362, '361-362-0-4')
# removed (363, 364, '363-364-0-4')
# removed (363, 366, '363-366-0-4')
# removed (363, 367, '363-367-0-4')
# removed (365, 364, '364-365-0-2')
# removed (364, 367, '364-367-0-4')
# removed (366, 367, '366-367-0-4')
# removed (366, 409, '366-409-0-4')
# removed (369, 368, '368-369-0-2')
# removed (368, 369, '368-369-0-4')
# removed (411, 760, '411-760-0-4')
# removed (619, 437, '437-619-0-2')
# removed (495, 496, '495-496-0-4')
# removed (498, 497, '497-498-0-2')
# removed (497, 498, '497-498-0-4')
# removed (619, 505, '505-619-0-2')
# removed (505, 619, '505-619-0-4')
# removed (552, 551, '551-552-0-2')
# removed (551, 552, '551-552-0-4')
# removed (655, 554, '554-655-0-2')
# removed (554, 1067, '554-1067-0-4')
# removed (655, 1067, '655-1067-0-4')
# removed (688, 689, '688-689-0-4')
# removed (700, 702, '700-702-0-4')
# removed (702, 807, '702-807-0-4')
# truncating street graph
# done truncating
# GIVEN LANES
# no edges
# truncating street graph
# done truncating
# GIVEN LANES
# no edges

# %%
import networkx as nx

Hs,Ls,As = zip(*HLAs)
A = nx.compose_all(As)
L = nx.compose_all(Ls)

snman.io.export_HLA(os.path.join(export_path, 'steps'), '_debug', L=L, A=A)

# %%
print('Reorder lanes')
snman.space_allocation.reorder_lanes(G, lanes_attribute=KEY_LANES_DESCRIPTION)
snman.space_allocation.reorder_lanes(G, lanes_attribute=KEY_LANES_DESCRIPTION_AFTER)

print('Normalize cycling infrastructure')
snman.space_allocation.normalize_cycling_lanes(G, lanes_key=KEY_LANES_DESCRIPTION)
snman.space_allocation.normalize_cycling_lanes(G, lanes_key=KEY_LANES_DESCRIPTION_AFTER)

snman.street_graph.organize_edge_directions(G)
# Out:
# Reorder lanes
# Normalize cycling infrastructure

# %%
print('Add elevation')
G = oxc.elevation.add_node_elevations_raster(
    G,
    os.path.join(inputs_path, 'switzerland', 'switzerland', 'ch_dhm_25', 'ch_dhm_2056.tif'),
    raster_crs=2056,
    graph_crs=CRS_internal,
    cpus=1
)
G = oxc.elevation.add_edge_grades(G, add_absolute=False)
# Out:
# Add elevation

# %%
snman.space_allocation.generate_lane_stats(G, lanes_attribute=KEY_LANES_DESCRIPTION)
snman.space_allocation.generate_lane_stats(G, lanes_attribute=KEY_LANES_DESCRIPTION_AFTER)

# %%
if 1:
    print('export G')
    snman.io.export_street_graph(
        G,
        os.path.join(export_path, 'G_edges.gpkg'),
        os.path.join(export_path, 'G_nodes.gpkg')
    )

if 1:
    print('export L before')
    L = snman.lane_graph.create_lane_graph(G, lanes_attribute=KEY_LANES_DESCRIPTION)
    snman.io.export_lane_geometries(
        L,
        os.path.join(export_path, 'lane_geometries_edges.gpkg'),
        os.path.join(export_path, 'lane_geometries_nodes.gpkg'),
        scaling=4
    )

if 1:
    print('export L after')
    L = snman.lane_graph.create_lane_graph(G, lanes_attribute=KEY_LANES_DESCRIPTION_AFTER)
    snman.io.export_lane_geometries(
        L,
        os.path.join(export_path, 'lane_geometries_rebuilt_edges.gpkg'),
        os.path.join(export_path, 'lane_geometries_rebuilt_nodes.gpkg'),
        scaling=4
    )
# Out:
# export G
# export L before
# export L after
