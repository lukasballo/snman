# %%
import geopandas
import r5py.sampledata.helsinki
import shapely

population_grid = geopandas.read_file(r5py.sampledata.helsinki.population_grid)

railway_station = geopandas.GeoDataFrame(
    {
        "id": ["railway_station"],
        "geometry": [shapely.Point(24.94152, 60.17066)]
    },
    crs="EPSG:4326",
)

overview_map = population_grid.explore("population", cmap="Reds")
overview_map = railway_station.explore(m=overview_map, marker_type="marker")
overview_map
# Out:
# C:\APPS\Anaconda3\envs\ebc39a\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7683ebcff3c43df7a065d6b305bb7eae {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7683ebcff3c43df7a065d6b305bb7eae&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7683ebcff3c43df7a065d6b305bb7eae = L.map(
#                 &quot;map_7683ebcff3c43df7a065d6b305bb7eae&quot;,
#                 {
#                     center: [60.16536527774946, 24.932467057927006],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_7683ebcff3c43df7a065d6b305bb7eae);
#
#
#
#
#
#             var tile_layer_4a43213e60f000a4931654a371ca6df1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7683ebcff3c43df7a065d6b305bb7eae);
#
#
#             map_7683ebcff3c43df7a065d6b305bb7eae.fitBounds(
#                 [[60.154132207744546, 24.90544814560493], [60.176598347754364, 24.959485970249084]],
#                 {}
#             );
#
#
#         function geo_json_15486b2db7ba372d79593692e141c949_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;#fdd0bc&quot;, &quot;fillColor&quot;: &quot;#fdd0bc&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;: case &quot;58&quot;:
#                     return {&quot;color&quot;: &quot;#fedecf&quot;, &quot;fillColor&quot;: &quot;#fedecf&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;#fcad90&quot;, &quot;fillColor&quot;: &quot;#fcad90&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;:
#                     return {&quot;color&quot;: &quot;#dc2924&quot;, &quot;fillColor&quot;: &quot;#dc2924&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;: case &quot;79&quot;: case &quot;88&quot;:
#                     return {&quot;color&quot;: &quot;#fff4ee&quot;, &quot;fillColor&quot;: &quot;#fff4ee&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;: case &quot;82&quot;:
#                     return {&quot;color&quot;: &quot;#fee5d9&quot;, &quot;fillColor&quot;: &quot;#fee5d9&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;: case &quot;78&quot;:
#                     return {&quot;color&quot;: &quot;#fc8666&quot;, &quot;fillColor&quot;: &quot;#fc8666&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;:
#                     return {&quot;color&quot;: &quot;#fb7656&quot;, &quot;fillColor&quot;: &quot;#fb7656&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8&quot;:
#                     return {&quot;color&quot;: &quot;#ea362a&quot;, &quot;fillColor&quot;: &quot;#ea362a&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;9&quot;:
#                     return {&quot;color&quot;: &quot;#fedbcc&quot;, &quot;fillColor&quot;: &quot;#fedbcc&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10&quot;: case &quot;68&quot;:
#                     return {&quot;color&quot;: &quot;#fdd4c2&quot;, &quot;fillColor&quot;: &quot;#fdd4c2&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;11&quot;:
#                     return {&quot;color&quot;: &quot;#fdc7b2&quot;, &quot;fillColor

# %%
population_grid
# Out:
#     id  population                                           geometry
# 0    0         389  POLYGON ((24.90545 60.16086, 24.90545 60.16311...
# 1    1         296  POLYGON ((24.90546 60.15862, 24.90545 60.16086...
# 2    2         636  POLYGON ((24.90547 60.15638, 24.90546 60.15862...
# 3    3        1476  POLYGON ((24.90547 60.15413, 24.90547 60.15638...
# 4    4          23  POLYGON ((24.90994 60.16535, 24.90994 60.16760...
# ..  ..         ...                                                ...
# 87  87        1047  POLYGON ((24.95497 60.16987, 24.95496 60.17211...
# 88  88          23  POLYGON ((24.95497 60.16762, 24.95497 60.16987...
# 89  89          86  POLYGON ((24.95498 60.16089, 24.95498 60.16313...
# 90  90         253  POLYGON ((24.95498 60.15865, 24.95498 60.16089...
# 91  91          72  POLYGON ((24.95498 60.15640, 24.95498 60.15865...
#
# [92 rows x 3 columns]

# %%
transport_network = r5py.TransportNetwork(
    r5py.sampledata.helsinki.osm_pbf,
    [r5py.sampledata.helsinki.gtfs],
)

# %%
import datetime

origins = population_grid.copy()
origins.geometry = origins.geometry.centroid

destinations = railway_station.copy()
# Out:
# C:\Users\lballo\AppData\Local\Temp\ipykernel_20300\3762918110.py:4: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   origins.geometry = origins.geometry.centroid

# %%
travel_time_matrix_computer = r5py.TravelTimeMatrixComputer(
    transport_network,
    origins=origins,
    destinations=destinations,
    departure=datetime.datetime(2022, 2, 22, 8, 30),
    transport_modes=[
        r5py.TransportMode.CAR,
        r5py.TransportMode.WALK,
    ],
)

travel_times = travel_time_matrix_computer.compute_travel_times()
travel_times.head()
# Out:
#    from_id            to_id  travel_time
# 0        0  railway_station            9
# 1        1  railway_station           10
# 2        2  railway_station           10
# 3        3  railway_station           13
# 4        4  railway_station            9

# %%
travel_times.to_csv("travel_times_to_helsinki_railway_station.csv")
